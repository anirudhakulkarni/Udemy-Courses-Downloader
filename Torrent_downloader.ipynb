# %% [markdown]
# # Torrent To Google Drive Downloader v2

# %% [markdown]
# ### Mount Google Drive
# To stream files we need to mount Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###Dependency
# https://www.libtorrent.org/

# %%
# !apt install python3-libtorrent
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libtorrent-rasterbar9
# Suggested packages:
#   libtorrent-rasterbar-dbg
# The following NEW packages will be installed:
#   libtorrent-rasterbar9 python3-libtorrent
# 0 upgraded, 2 newly installed, 0 to remove and 13 not upgraded.
# Need to get 1,569 kB of archives.
# After this operation, 5,718 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libtorrent-rasterbar9 amd64 1.1.5-1build1 [1,258 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-libtorrent amd64 1.1.5-1build1 [310 kB]
# Fetched 1,569 kB in 1s (1,137 kB/s)
# Selecting previously unselected package libtorrent-rasterbar9.
# (Reading database ... 146374 files and directories currently installed.)
# Preparing to unpack .../libtorrent-rasterbar9_1.1.5-1build1_amd64.deb ...
# Unpacking libtorrent-rasterbar9 (1.1.5-1build1) ...
# Selecting previously unselected package python3-libtorrent.
# Preparing to unpack .../python3-libtorrent_1.1.5-1build1_amd64.deb ...
# Unpacking python3-libtorrent (1.1.5-1build1) ...
# Setting up libtorrent-rasterbar9 (1.1.5-1build1) ...
# Setting up python3-libtorrent (1.1.5-1build1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link

# %% [markdown]
# ### Code to download torrent
# Variable **link** stores the link string.

# %%
import libtorrent as lt
import time
import datetime

ses = lt.session()
ses.listen_on(6881, 6891)
params = {
    'save_path': '/content/drive/My Drive/Torrent/',
    'storage_mode': lt.storage_mode_t(2),
    'paused': False,
    'auto_managed': True,
    'duplicate_is_error': True}

# This is the link to replace
# replace this with magnet link
link = "" 
print(link)

handle = lt.add_magnet_uri(ses, link, params)
ses.start_dht()
2
begin = time.time()
print(datetime.datetime.now())

print ('Downloading Metadata...')
while (not handle.has_metadata()):
    time.sleep(1)
print ('Got Metadata, Starting Torrent Download...')

print("Starting", handle.name())

while (handle.status().state != lt.torrent_status.seeding):
    s = handle.status()
    state_str = ['queued', 'checking', 'downloading metadata', \
            'downloading', 'finished', 'seeding', 'allocating']
    print ('%.2f%% complete (down: %.1f kb/s up: %.1f kB/s peers: %d) %s ' % \
            (s.progress * 100, s.download_rate / 1000, s.upload_rate / 1000, \
            s.num_peers, state_str[s.state]))
    time.sleep(5)

end = time.time()
print(handle.name(), "COMPLETE")

print("Elapsed Time: ",int((end-begin)//60),"min :", int((end-begin)%60), "sec")

print(datetime.datetime.now())
# Out:
# magnet:?xt=urn:btih:d75a8f3062c0a7edd155d4d6bfdc7e4b13aabaea&dn=%5BFreeCourseSite.com%5D+Udemy+-+Learn+OAuth+2.0+-+Get+started+as+an+API+Security+Expert
# 2021-01-30 10:34:59.043751
# Downloading Metadata...
# Got Metadata, Starting Torrent Download...
# Starting [FreeCourseSite.com] Udemy - Learn OAuth 2.0 - Get started as an API Security Expert
# 0.00% complete (down: 8.1 kb/s up: 0.4 kB/s peers: 1) downloading
# 0.09% complete (down: 122.6 kb/s up: 4.0 kB/s peers: 1) downloading
# 0.36% complete (down: 332.1 kb/s up: 10.2 kB/s peers: 1) downloading
# 0.65% complete (down: 472.1 kb/s up: 14.3 kB/s peers: 1) downloading
# 0.95% complete (down: 510.1 kb/s up: 15.6 kB/s peers: 1) downloading
# 1.28% complete (down: 610.4 kb/s up: 18.9 kB/s peers: 1) downloading
# 1.66% complete (down: 666.5 kb/s up: 20.6 kB/s peers: 1) downloading
# 2.08% complete (down: 705.3 kb/s up: 21.8 kB/s peers: 1) downloading
# 2.58% complete (down: 834.1 kb/s up: 25.8 kB/s peers: 1) downloading
# 3.00% complete (down: 774.3 kb/s up: 23.8 kB/s peers: 1) downloading
# 3.35% complete (down: 701.1 kb/s up: 21.4 kB/s peers: 1) downloading
# 3.68% complete (down: 649.1 kb/s up: 19.9 kB/s peers: 1) downloading
# 4.03% complete (down: 650.0 kb/s up: 20.0 kB/s peers: 1) downloading
# 4.63% complete (down: 932.3 kb/s up: 29.0 kB/s peers: 1) downloading
# 5.49% complete (down: 1315.8 kb/s up: 41.0 kB/s peers: 1) downloading
# 6.26% complete (down: 1404.8 kb/s up: 43.5 kB/s peers: 1) downloading
# 7.06% complete (down: 1404.4 kb/s up: 43.5 kB/s peers: 1) downloading
# 7.83% complete (down: 1421.5 kb/s up: 43.9 kB/s peers: 1) downloading
# 8.57% complete (down: 1370.5 kb/s up: 42.3 kB/s peers: 1) downloading
# 9.01% complete (down: 1011.9 kb/s up: 30.8 kB/s peers: 1) downloading
# 9.55% complete (down: 960.0 kb/s up: 29.4 kB/s peers: 1) downloading
# 10.32% complete (down: 1229.4 kb/s up: 38.1 kB/s peers: 1) downloading
# 11.33% complete (down: 1603.5 kb/s up: 49.8 kB/s peers: 1) downloading
# 12.39% complete (down: 1972.6 kb/s up: 60.9 kB/s peers: 1) downloading
# 12.90% complete (down: 1250.4 kb/s up: 38.4 kB/s peers: 1) downloading
# 13.64% complete (down: 1301.2 kb/s up: 40.2 kB/s peers: 1) downloading
# 14.17% complete (down: 1104.7 kb/s up: 33.9 kB/s peers: 1) downloading
# 14.65% complete (down: 944.2 kb/s up: 28.8 kB/s peers: 1) downloading
# 15.09% complete (down: 855.2 kb/s up: 26.2 kB/s peers: 1) downloading
# 15.77% complete (down: 1116.1 kb/s up: 34.6 kB/s peers: 1) downloading
# 16.72% complete (down: 1493.6 kb/s up: 46.5 kB/s peers: 1) downloading
# 17.88% complete (down: 1907.4 kb/s up: 59.2 kB/s peers: 1) downloading
# 18.86% complete (down: 1835.3 kb/s up: 56.7 kB/s peers: 1) downloading
# 19.60% complete (down: 1519.5 kb/s up: 46.9 kB/s peers: 1) downloading
# 19.86% complete (down: 856.2 kb/s up: 26.3 kB/s peers: 0) downloading
# 19.86% complete (down: 280.6 kb/s up: 8.6 kB/s peers: 0) downloading
# 19.86% complete (down: 91.9 kb/s up: 2.8 kB/s peers: 0) downloading
# 19.86% complete (down: 30.1 kb/s up: 0.9 kB/s peers: 0) downloading
# 19.86% complete (down: 9.9 kb/s up: 0.3 kB/s peers: 0) downloading
# 19.86% complete (down: 3.2 kb/s up: 0.1 kB/s peers: 0) downloading
# 19.86% complete (down: 1.1 kb/s up: 0.0 kB/s peers: 0) downloading
# 19.86% complete (down: 0.3 kb/s up: 0.0 kB/s peers: 0) downloading
# 19.86% complete (down: 0.1 kb/s up: 0.0 kB/s peers: 0) downloading
# 19.86% complete (down: 0.0 kb/s up: 0.0 kB/s peers: 0) downloading
# 19.86% complete (down: 0.0 kb/s up: 0.0 kB/s peers: 0) downloading
# 19.86% complete (down: 0.0 kb/s up: 0.0 kB/s peers: 0) downloading
# 19.86% complete (down: 0.0 kb/s up: 0.0 kB/s peers: 0) downloading
# 19.86% complete (down: 0.0 kb/s up: 0.0 kB/s peers: 0) downloading
# 19.86% complete (down: 0.0 kb/s up: 0.0 kB/s peers: 0) downloading
# 19.86% complete (down: 0.0 kb/s up: 0.0 kB/s peers: 0) downloading
# 19.86% complete (down: 0.0 kb/s up: 0.0 kB/s peers: 0) downloading
# 19.86% complete (down: 0.0 kb/s up: 0.0 kB/s peers: 0) downloading
# 19.86% complete (down: 0.2 kb/s up: 0.1 kB/s peers: 1) downloading
# 20.01% complete (down: 145.0 kb/s up: 4.7 kB/s peers: 1) downloading
# 20.34% complete (down: 476.7 kb/s up: 14.6 kB/s peers: 1) downloading
# 20.81% complete (down: 660.1 kb/s up: 20.3 kB/s peers: 1) downloading
# 20.90% complete (down: 378.7 kb/s up: 11.1 kB/s peers: 1) downloading
# 21.17% complete (down: 413.7 kb/s up: 12.5 kB/s peers: 1) downloading
# 21.58% complete (down: 653.7 kb/s up: 20.2 kB/s peers: 1) downloading
# 22.06% complete (down: 812.8 kb/s up: 25.1 kB/s peers: 1) downloading
# 22.53% complete (down: 818.2 kb/s up: 25.3 kB/s peers: 1) downloading
# 23.01% complete (down: 855.9 kb/s up: 26.5 kB/s peers: 1) downloading
# 23.63% complete (down: 1017.7 kb/s up: 31.6 kB/s peers: 1) downloading
# 24.19% complete (down: 1010.2 kb/s up: 31.2 kB/s peers: 1) downloading
# 24.90% complete (down: 1182.9 kb/s up: 36.7 kB/s peers: 1) downloading
# 25.47% complete (down: 1079.6 kb/s up: 33.3 kB/s peers: 1) downloading
# 26.03% complete (down: 1098.7 kb/s up: 33.9 kB/s peers: 1) downloading
# 26.71% complete (down: 1134.6 kb/s up: 35.0 kB/s peers: 1) downloading
# 27.25% complete (down: 1058.7 kb/s up: 32.6 kB/s peers: 1) downloading
# 27.96% complete (down: 1231.0 kb/s up: 38.1 kB/s peers: 1) downloading
# 28.34% complete (down: 895.6 kb/s up: 27.3 kB/s peers: 1) downloading
# 28.91% complete (down: 955.7 kb/s up: 29.4 kB/s peers: 1) downloading
# 29.71% complete (down: 1271.2 kb/s up: 39.5 kB/s peers: 1) downloading
# 30.75% complete (down: 1661.5 kb/s up: 51.7 kB/s peers: 1) downloading
# 31.57% complete (down: 1553.0 kb/s up: 48.0 kB/s peers: 1) downloading
# 32.49% complete (down: 1611.9 kb/s up: 50.0 kB/s peers: 1) downloading
# 33.65% complete (down: 1919.7 kb/s up: 59.6 kB/s peers: 1) downloading
# 34.81% complete (down: 2111.5 kb/s up: 65.2 kB/s peers: 1) downloading
# 35.70% complete (down: 1769.2 kb/s up: 54.8 kB/s peers: 1) downloading
# 36.83% complete (down: 1939.6 kb/s up: 60.2 kB/s peers: 1) downloading
# 38.16% complete (down: 2266.9 kb/s up: 70.3 kB/s peers: 1) downloading
# 39.02% complete (down: 1905.0 kb/s up: 58.7 kB/s peers: 1) downloading
# 39.67% complete (down: 1371.1 kb/s up: 42.4 kB/s peers: 1) downloading
# 40.20% complete (down: 1177.0 kb/s up: 36.2 kB/s peers: 1) downloading
# 40.65% complete (down: 898.8 kb/s up: 27.4 kB/s peers: 1) downloading
# 41.30% complete (down: 1101.2 kb/s up: 34.0 kB/s peers: 1) downloading
# 41.80% complete (down: 1010.7 kb/s up: 31.1 kB/s peers: 1) downloading
# 42.25% complete (down: 892.6 kb/s up: 27.5 kB/s peers: 1) downloading
# 42.87% complete (down: 1127.8 kb/s up: 35.0 kB/s peers: 1) downloading
# 43.73% complete (down: 1402.2 kb/s up: 43.6 kB/s peers: 1) downloading
# 44.80% complete (down: 1792.1 kb/s up: 55.4 kB/s peers: 1) downloading
# 45.42% complete (down: 1319.9 kb/s up: 40.8 kB/s peers: 1) downloading
# 45.75% complete (down: 829.6 kb/s up: 25.0 kB/s peers: 1) downloading
# 46.13% complete (down: 773.3 kb/s up: 23.5 kB/s peers: 1) downloading
# 46.61% complete (down: 804.8 kb/s up: 24.8 kB/s peers: 1) downloading
# 47.15% complete (down: 925.8 kb/s up: 28.6 kB/s peers: 1) downloading
# 47.47% complete (down: 698.8 kb/s up: 21.3 kB/s peers: 1) downloading
# 47.97% complete (down: 875.3 kb/s up: 27.1 kB/s peers: 1) downloading
# 48.27% complete (down: 650.0 kb/s up: 19.8 kB/s peers: 1) downloading
# 48.74% complete (down: 809.7 kb/s up: 25.0 kB/s peers: 1) downloading
# 49.28% complete (down: 903.8 kb/s up: 27.9 kB/s peers: 1) downloading
# 49.87% complete (down: 1047.9 kb/s up: 32.5 kB/s peers: 1) downloading
# 50.70% complete (down: 1368.8 kb/s up: 42.6 kB/s peers: 1) downloading
# 51.74% complete (down: 1730.3 kb/s up: 53.8 kB/s peers: 1) downloading
# 52.45% complete (down: 1479.1 kb/s up: 45.9 kB/s peers: 1) downloading
# 53.40% complete (down: 1658.1 kb/s up: 51.5 kB/s peers: 1) downloading
# 54.55% complete (down: 1971.4 kb/s up: 61.2 kB/s peers: 1) downloading
# 55.29% complete (down: 1565.6 kb/s up: 48.3 kB/s peers: 1) downloading
# 55.53% complete (down: 842.9 kb/s up: 25.2 kB/s peers: 1) downloading
# 56.01% complete (down: 892.1 kb/s up: 27.3 kB/s peers: 1) downloading
# 56.72% complete (down: 1179.0 kb/s up: 36.6 kB/s peers: 1) downloading
# 57.66% complete (down: 1550.2 kb/s up: 48.2 kB/s peers: 1) downloading
# 58.38% complete (down: 1374.3 kb/s up: 42.5 kB/s peers: 1) downloading
# 59.06% complete (down: 1238.7 kb/s up: 38.1 kB/s peers: 1) downloading
# 59.47% complete (down: 937.9 kb/s up: 28.5 kB/s peers: 1) downloading
# 60.10% complete (down: 1099.9 kb/s up: 34.0 kB/s peers: 1) downloading
# 60.63% complete (down: 1016.8 kb/s up: 31.3 kB/s peers: 1) downloading
# 61.13% complete (down: 913.0 kb/s up: 28.0 kB/s peers: 1) downloading
# 61.76% complete (down: 1065.4 kb/s up: 33.0 kB/s peers: 1) downloading
# 62.62% complete (down: 1410.5 kb/s up: 43.9 kB/s peers: 1) downloading
# 63.68% complete (down: 1819.5 kb/s up: 56.5 kB/s peers: 1) downloading
# 64.60% complete (down: 1682.4 kb/s up: 52.1 kB/s peers: 1) downloading
# 65.49% complete (down: 1640.7 kb/s up: 50.7 kB/s peers: 1) downloading
# 66.15% complete (down: 1333.5 kb/s up: 41.2 kB/s peers: 1) downloading
# 66.71% complete (down: 1105.8 kb/s up: 33.9 kB/s peers: 1) downloading
# 67.42% complete (down: 1252.1 kb/s up: 38.6 kB/s peers: 1) downloading
# 67.89% complete (down: 1009.5 kb/s up: 31.0 kB/s peers: 1) downloading
# 68.31% complete (down: 830.5 kb/s up: 25.3 kB/s peers: 1) downloading
# 68.64% complete (down: 670.3 kb/s up: 20.4 kB/s peers: 1) downloading
# 69.11% complete (down: 827.0 kb/s up: 25.6 kB/s peers: 1) downloading
# 69.46% complete (down: 659.3 kb/s up: 20.2 kB/s peers: 1) downloading
# 69.70% complete (down: 496.3 kb/s up: 15.0 kB/s peers: 1) downloading
# 70.09% complete (down: 684.8 kb/s up: 21.1 kB/s peers: 1) downloading
# 70.41% complete (down: 720.9 kb/s up: 22.3 kB/s peers: 1) downloading
# 71.01% complete (down: 847.6 kb/s up: 26.2 kB/s peers: 1) downloading
# 71.30% complete (down: 650.3 kb/s up: 19.9 kB/s peers: 1) downloading
# 71.57% complete (down: 540.2 kb/s up: 16.5 kB/s peers: 1) downloading
# 72.01% complete (down: 697.9 kb/s up: 21.6 kB/s peers: 1) downloading
# 72.25% complete (down: 559.3 kb/s up: 17.0 kB/s peers: 1) downloading
# 72.64% complete (down: 615.9 kb/s up: 18.9 kB/s peers: 1) downloading
# 72.93% complete (down: 552.6 kb/s up: 16.9 kB/s peers: 1) downloading
# 73.23% complete (down: 723.8 kb/s up: 22.4 kB/s peers: 1) downloading
# 73.68% complete (down: 617.5 kb/s up: 18.9 kB/s peers: 1) downloading
# 74.24% complete (down: 890.6 kb/s up: 27.6 kB/s peers: 1) downloading
# 74.98% complete (down: 1223.0 kb/s up: 37.9 kB/s peers: 1) downloading
# 75.51% complete (down: 1067.8 kb/s up: 32.9 kB/s peers: 1) downloading
# 75.78% complete (down: 663.6 kb/s up: 19.9 kB/s peers: 1) downloading
# 75.99% complete (down: 487.6 kb/s up: 14.6 kB/s peers: 1) downloading
# 76.34% complete (down: 594.6 kb/s up: 18.3 kB/s peers: 1) downloading
# 76.67% complete (down: 635.0 kb/s up: 19.6 kB/s peers: 1) downloading
# 77.05% complete (down: 666.9 kb/s up: 20.6 kB/s peers: 1) downloading
# 77.35% complete (down: 594.1 kb/s up: 18.2 kB/s peers: 1) downloading
# 77.68% complete (down: 584.4 kb/s up: 17.9 kB/s peers: 1) downloading
# 78.09% complete (down: 687.2 kb/s up: 21.2 kB/s peers: 1) downloading
# 78.51% complete (down: 746.7 kb/s up: 23.1 kB/s peers: 1) downloading
# 79.07% complete (down: 962.0 kb/s up: 30.0 kB/s peers: 1) downloading
# 79.52% complete (down: 842.5 kb/s up: 26.0 kB/s peers: 1) downloading
# 79.99% complete (down: 875.3 kb/s up: 27.0 kB/s peers: 1) downloading
# 80.52% complete (down: 897.9 kb/s up: 27.7 kB/s peers: 1) downloading
# 81.09% complete (down: 1003.7 kb/s up: 31.0 kB/s peers: 1) downloading
# 81.44% complete (down: 752.0 kb/s up: 22.9 kB/s peers: 1) downloading
# 81.98% complete (down: 908.5 kb/s up: 28.1 kB/s peers: 1) downloading
# 82.63% complete (down: 1088.5 kb/s up: 33.7 kB/s peers: 1) downloading
# 83.22% complete (down: 1107.5 kb/s up: 34.2 kB/s peers: 1) downloading
# 84.05% complete (down: 1396.3 kb/s up: 43.4 kB/s peers: 1) downloading
# 84.38% complete (down: 847.1 kb/s up: 25.5 kB/s peers: 1) downloading
# 84.79% complete (down: 784.7 kb/s up: 23.9 kB/s peers: 1) downloading
# 85.44% complete (down: 1060.0 kb/s up: 32.8 kB/s peers: 1) downloading
# 86.16% complete (down: 1239.3 kb/s up: 38.3 kB/s peers: 1) downloading
# 86.54% complete (down: 870.0 kb/s up: 26.4 kB/s peers: 1) downloading
# 86.93% complete (down: 800.7 kb/s up: 24.5 kB/s peers: 1) downloading
# 87.28% complete (down: 687.6 kb/s up: 21.0 kB/s peers: 1) downloading
# 87.61% complete (down: 635.3 kb/s up: 19.5 kB/s peers: 1) downloading
# 88.05% complete (down: 745.7 kb/s up: 23.1 kB/s peers: 1) downloading
# 88.53% complete (down: 819.0 kb/s up: 25.3 kB/s peers: 1) downloading
# 89.15% complete (down: 1003.8 kb/s up: 31.2 kB/s peers: 1) downloading
# 89.51% complete (down: 790.0 kb/s up: 24.2 kB/s peers: 1) downloading
# 89.83% complete (down: 660.0 kb/s up: 20.1 kB/s peers: 1) downloading
# 90.04% complete (down: 465.8 kb/s up: 14.0 kB/s peers: 1) downloading
# 90.37% complete (down: 544.1 kb/s up: 16.7 kB/s peers: 1) downloading
# 90.78% complete (down: 693.0 kb/s up: 21.4 kB/s peers: 1) downloading
# 90.93% complete (down: 429.2 kb/s up: 12.9 kB/s peers: 1) downloading
# 91.23% complete (down: 481.4 kb/s up: 14.7 kB/s peers: 1) downloading
# 91.52% complete (down: 574.9 kb/s up: 17.8 kB/s peers: 1) downloading
# 92.03% complete (down: 796.8 kb/s up: 24.8 kB/s peers: 1) downloading
# 92.77% complete (down: 1158.6 kb/s up: 36.1 kB/s peers: 1) downloading
# 93.24% complete (down: 1010.0 kb/s up: 31.1 kB/s peers: 1) downloading
# 93.54% complete (down: 692.1 kb/s up: 21.0 kB/s peers: 1) downloading
# 93.80% complete (down: 549.1 kb/s up: 16.7 kB/s peers: 1) downloading
# 94.07% complete (down: 509.1 kb/s up: 15.5 kB/s peers: 1) downloading
# 94.31% complete (down: 474.7 kb/s up: 14.5 kB/s peers: 1) downloading
# 94.78% complete (down: 750.7 kb/s up: 23.3 kB/s peers: 1) downloading
# 95.52% complete (down: 1116.4 kb/s up: 34.8 kB/s peers: 1) downloading
# 96.47% complete (down: 1522.5 kb/s up: 47.5 kB/s peers: 1) downloading
# 97.01% complete (down: 1154.9 kb/s up: 35.4 kB/s peers: 1) downloading
# 97.60% complete (down: 1111.6 kb/s up: 34.2 kB/s peers: 1) downloading
# 98.22% complete (down: 1082.7 kb/s up: 33.3 kB/s peers: 1) downloading
# 98.49% complete (down: 697.1 kb/s up: 20.9 kB/s peers: 1) downloading
# 98.96% complete (down: 815.1 kb/s up: 25.1 kB/s peers: 1) downloading
# 99.50% complete (down: 902.9 kb/s up: 27.9 kB/s peers: 1) downloading
# 99.73% complete (down: 565.0 kb/s up: 17.0 kB/s peers: 1) downloading
# [FreeCourseSite.com] Udemy - Learn OAuth 2.0 - Get started as an API Security Expert COMPLETE
# Elapsed Time:  16 min : 48 sec
# 2021-01-30 10:51:48.036788
